# %% [markdown]
# <a href="https://colab.research.google.com/github/mpumasupa/jupyter-exploration1/blob/main/My_First_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# My first markdown cell in Jupiter.

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# A line was added to see how the version history of the notebooks works.
